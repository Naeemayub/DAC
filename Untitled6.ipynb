# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("compensation data.csv")

# %%
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25973 entries, 0 to 25972
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   experience_coding  25973 non-null  float64
#  1   python_user        25973 non-null  bool
#  2   r_user             25973 non-null  bool
#  3   sql_user           25973 non-null  bool
#  4   most_used          16835 non-null  object
#  5   compensation       25973 non-null  int64
# dtypes: bool(3), float64(1), int64(1), object(1)
# memory usage: 685.0+ KB

# %%
df.shape
# Out:
# (25973, 6)

# %%
x = [4,5,6,30,33]
new_Series = pd.Series(x)
new_Series
# Out:
# 0     4
# 1     5
# 2     6
# 3    30
# 4    33
# dtype: int64

# %%
new_Series = pd.Series(x, index = ['a','b','c','d','e'])
new_Series
# Out:
# a     4
# b     5
# c     6
# d    30
# e    33
# dtype: int64

# %%
df1 = pd.DataFrame(
            {
                'Name': ['naeem', 'kiran', 'emaan', 'eissa', 'abduallah'], 
                'Age' : [44,40,12,6,7]
            })

# %%
df1
# Out:
#         Name  Age
# 0      naeem   44
# 1      kiran   40
# 2      emaan   12
# 3      eissa    6
# 4  abduallah    7

# %%
df1 = df1.set_index('Name')
df1
# Out:
#            Age
# Name
# naeem       44
# kiran       40
# emaan       12
# eissa        6
# abduallah    7

# %%
from sklearn.datasets import fetch_california_housing

# %%
df2 = fetch_california_housing(as_frame=True).frame

# %%
df2
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df.head()
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
#
#    compensation
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288

# %%
df.tail()
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 25968         15800
# 25969         62456
# 25970           923
# 25971         60609
# 25972           493

# %%
df.sample()
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 12624                4.1         True    True      True  Scikit-learn
#
#        compensation
# 12624          8730

# %%
df.columns
# Out:
# Index(['experience_coding', 'python_user', 'r_user', 'sql_user', 'most_used',
#        'compensation'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['experience_coding',
#  'python_user',
#  'r_user',
#  'sql_user',
#  'most_used',
#  'compensation']

# %%
df = pd.options.display.max_columns = 5

# %%
df2
# Out:
#        MedInc  HouseAge  ...  Longitude  MedHouseVal
# 0      8.3252      41.0  ...    -122.23        4.526
# 1      8.3014      21.0  ...    -122.22        3.585
# 2      7.2574      52.0  ...    -122.24        3.521
# 3      5.6431      52.0  ...    -122.25        3.413
# 4      3.8462      52.0  ...    -122.25        3.422
# ...       ...       ...  ...        ...          ...
# 20635  1.5603      25.0  ...    -121.09        0.781
# 20636  2.5568      18.0  ...    -121.21        0.771
# 20637  1.7000      17.0  ...    -121.22        0.923
# 20638  1.8672      18.0  ...    -121.32        0.847
# 20639  2.3886      16.0  ...    -121.24        0.894
#
# [20640 rows x 9 columns]

# %%
pd.options.display.max_columns = None

# %%
df2
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df2.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
df2
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df2.HouseAge.sum()
# Out:
# np.float64(591119.0)

# %%
df2.HouseAge.mean()
# Out:
# np.float64(28.639486434108527)

# %%
df2.HouseAge.mode()
# Out:
# 0    52.0
# Name: HouseAge, dtype: float64

# %%
df2.HouseAge.median()
# Out:
# np.float64(29.0)

# %%
df2.HouseAge.hist(bins=20)
# Out:
# <Axes: >

# %%
import yfinance as yf

# %%
gold = yf.download('gold')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10094 entries, 1985-02-13 to 2025-03-07
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, GOLD)   10094 non-null  float64
#  1   (High, GOLD)    10094 non-null  float64
#  2   (Low, GOLD)     10094 non-null  float64
#  3   (Open, GOLD)    10094 non-null  float64
#  4   (Volume, GOLD)  10094 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 473.2 KB

# %%
gold.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
import matplotlib.pyplot as plt
plt.plot(gold.Close)

# %%
df4 = pd.DataFrame({

    'name' : ['Naeem','Kiran', 'Emaan', 'Eissa', 'Abdullah'],
    'age' :  [44,40,12,6,5],
    'gender' : ['m','f','f','m','m']
})

# %%
df4
# Out:
#        name  age gender
# 0     Naeem   44      m
# 1     Kiran   40      f
# 2     Emaan   12      f
# 3     Eissa    6      m
# 4  Abdullah    5      m

# %%
df4.loc[1]
# Out:
# name      Kiran
# age          40
# gender        f
# Name: 1, dtype: object

# %%
df4 = df4.set_index('name')

# %%
df4
# Out:
#           age gender
# name
# Naeem      44      m
# Kiran      40      f
# Emaan      12      f
# Eissa       6      m
# Abdullah    5      m

# %%
df4.loc['Naeem', 'gender'] = 'M'

# %%
df4
# Out:
#           age gender
# name
# Naeem      44      M
# Kiran      40      f
# Emaan      12      f
# Eissa       6      m
# Abdullah    5      m

# %%
df4.at['Naeem','gender']
# Out:
# 'M'

# %%
df4.iat[1,0]
# Out:
# np.int64(40)

# %%
df4.loc['pidda'] = [0,'m']

# %%
df4
# Out:
#           age gender
# name
# Naeem      44      M
# Kiran      40      f
# Emaan      12      f
# Eissa       6      m
# Abdullah    5      m
# pidda       0      m

# %%
df4.loc['tida'] = 1

# %%
df4
# Out:
#           age gender
# name
# Naeem      44      M
# Kiran      40      f
# Emaan      12      f
# Eissa       6      m
# Abdullah    5      m
# pidda       0      m
# tida        1      1

# %%
df4.loc['tida','gender' ] = 'M'

# %%
df4
# Out:
#           age gender
# name
# Naeem      44      M
# Kiran      40      f
# Emaan      12      f
# Eissa       6      m
# Abdullah    5      m
# pidda       0      m
# tida        1      M

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Naeem to tida
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     7 non-null      int64
#  1   gender  7 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 468.0+ bytes

# %%
df4.reset_index(inplace=True)

# %%
df4
# Out:
#        name  age gender
# 0     Naeem   44      M
# 1     Kiran   40      f
# 2     Emaan   12      f
# 3     Eissa    6      m
# 4  Abdullah    5      m
# 5     pidda    0      m
# 6      tida    1      M

# %%
df
# Out:
# 5

# %%
df1
# Out:
#            Age
# Name
# naeem       44
# kiran       40
# emaan       12
# eissa        6
# abduallah    7

# %%
df2
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df2.iloc[2,1]
# Out:
# np.float64(52.0)

# %%
df2.loc[2,'HouseAge']
# Out:
# np.float64(52.0)
