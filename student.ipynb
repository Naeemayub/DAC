# %%
import csv

# %%
file_name = open('student data.csv', mode='r')

# %%
file_name
# Out:
# <_io.TextIOWrapper name='student data.csv' mode='r' encoding='cp1252'>

# %%
dir(csv)
# Out:
# ['Dialect',
#  'DictReader',
#  'DictWriter',
#  'Error',
#  'QUOTE_ALL',
#  'QUOTE_MINIMAL',
#  'QUOTE_NONE',
#  'QUOTE_NONNUMERIC',
#  'QUOTE_NOTNULL',
#  'QUOTE_STRINGS',
#  'Sniffer',
#  'StringIO',
#  '_Dialect',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__version__',
#  'excel',
#  'excel_tab',
#  'field_size_limit',
#  'get_dialect',
#  'list_dialects',
#  're',
#  'reader',
#  'register_dialect',
#  'types',
#  'unix_dialect',
#  'unregister_dialect',
#  'writer']

# %%
read = csv.reader(file_name)

# %%
read

# %%
data = list(read)

# %%
data
# Out:
# [['roll no', 'Name', 'Chemistry', 'Physics', 'Math'],
#  [],
#  ['101', 'Aliza', '50', '23', '87'],
#  [],
#  ['102', 'Fareed', '45', '24', '88'],
#  [],
#  ['103', 'Basit', '46', '25', '89'],
#  [],
#  ['104', 'Abdullah', '47', '26', '90'],
#  [],
#  ['105', 'Ali', '48', '27', '67'],
#  [],
#  ['106', 'Mubashir', '49', '28', '68'],
#  [],
#  ['107', 'Waleed', '50', '29', '69'],
#  [],
#  ['108', 'Mansoor', '51', '30', '70'],
#  [],
#  ['109', 'Zain', '52', '31', '71'],
#  [],
#  ['110', 'Mohsin', '53', '67', '72'],
#  [],
#  ['111', 'Shahmeer', '54', '68', '73'],
#  [],
#  ['112', 'Rao', '55', '69', '74'],
#  [],
#  ['113', 'Aurangzeb', '56', '70', '75'],
#  [],
#  ['114', 'Zeeshan', '57', '71', '76'],
#  [],
#  ['115', 'Hamna', '58', '72', '77'],
#  [],
#  ['116', 'Hamza', '59', '73', '78'],
#  [],
#  ['117', 'Khalid', '60', '74', '79'],
#  [],
#  ['118', 'Behroz', '61', '75', '80'],
#  [],
#  ['119', 'Justin', '62', '76', '81'],
#  [],
#  ['120', 'Danish', '63', '77', '82'],
# ...

# %%
header = data[0]

# %%
stud_data = data[1:]

# %%
stud_data
# Out:
# [[],
#  ['101', 'Aliza', '50', '23', '87'],
#  [],
#  ['102', 'Fareed', '45', '24', '88'],
#  [],
#  ['103', 'Basit', '46', '25', '89'],
#  [],
#  ['104', 'Abdullah', '47', '26', '90'],
#  [],
#  ['105', 'Ali', '48', '27', '67'],
#  [],
#  ['106', 'Mubashir', '49', '28', '68'],
#  [],
#  ['107', 'Waleed', '50', '29', '69'],
#  [],
#  ['108', 'Mansoor', '51', '30', '70'],
#  [],
#  ['109', 'Zain', '52', '31', '71'],
#  [],
#  ['110', 'Mohsin', '53', '67', '72'],
#  [],
#  ['111', 'Shahmeer', '54', '68', '73'],
#  [],
#  ['112', 'Rao', '55', '69', '74'],
#  [],
#  ['113', 'Aurangzeb', '56', '70', '75'],
#  [],
#  ['114', 'Zeeshan', '57', '71', '76'],
#  [],
#  ['115', 'Hamna', '58', '72', '77'],
#  [],
#  ['116', 'Hamza', '59', '73', '78'],
#  [],
#  ['117', 'Khalid', '60', '74', '79'],
#  [],
#  ['118', 'Behroz', '61', '75', '80'],
#  [],
#  ['119', 'Justin', '62', '76', '81'],
#  [],
#  ['120', 'Danish', '63', '77', '82'],
#  [],
#  ['121', 'Kainat', '64', '78', '83'],
#  [],
# ...

# %%
stud_data[0]
# Out:
# []

# %%
new_stud_data = []
for i in stud_data:
    if i == []:
        pass
    else:
        new_stud_data.append(i)

# %%
new_stud_data
# Out:
# [['101', 'Aliza', '50', '23', '87'],
#  ['102', 'Fareed', '45', '24', '88'],
#  ['103', 'Basit', '46', '25', '89'],
#  ['104', 'Abdullah', '47', '26', '90'],
#  ['105', 'Ali', '48', '27', '67'],
#  ['106', 'Mubashir', '49', '28', '68'],
#  ['107', 'Waleed', '50', '29', '69'],
#  ['108', 'Mansoor', '51', '30', '70'],
#  ['109', 'Zain', '52', '31', '71'],
#  ['110', 'Mohsin', '53', '67', '72'],
#  ['111', 'Shahmeer', '54', '68', '73'],
#  ['112', 'Rao', '55', '69', '74'],
#  ['113', 'Aurangzeb', '56', '70', '75'],
#  ['114', 'Zeeshan', '57', '71', '76'],
#  ['115', 'Hamna', '58', '72', '77'],
#  ['116', 'Hamza', '59', '73', '78'],
#  ['117', 'Khalid', '60', '74', '79'],
#  ['118', 'Behroz', '61', '75', '80'],
#  ['119', 'Justin', '62', '76', '81'],
#  ['120', 'Danish', '63', '77', '82'],
#  ['121', 'Kainat', '64', '78', '83'],
#  ['122', 'Sameer', '65', '79', '84'],
#  ['123', 'Raza', '66', '80', '85'],
#  ['124', 'Kumar', '67', '81', '86'],
#  ['125', 'Komal', '68', '82', '87'],
# ...

# %%
for i in new_stud_data:
    total = float(i[-1])+float(i[-2])+float(i[-3])
    percentage = round((total/300)*100,2)
    i.append(total)
    i.append(percentage)
new_stud_data
# Out:
# [['101', 'Aliza', '50', '23', '87', 160.0, 53.33],
#  ['102', 'Fareed', '45', '24', '88', 157.0, 52.33],
#  ['103', 'Basit', '46', '25', '89', 160.0, 53.33],
#  ['104', 'Abdullah', '47', '26', '90', 163.0, 54.33],
#  ['105', 'Ali', '48', '27', '67', 142.0, 47.33],
#  ['106', 'Mubashir', '49', '28', '68', 145.0, 48.33],
#  ['107', 'Waleed', '50', '29', '69', 148.0, 49.33],
#  ['108', 'Mansoor', '51', '30', '70', 151.0, 50.33],
#  ['109', 'Zain', '52', '31', '71', 154.0, 51.33],
#  ['110', 'Mohsin', '53', '67', '72', 192.0, 64.0],
#  ['111', 'Shahmeer', '54', '68', '73', 195.0, 65.0],
#  ['112', 'Rao', '55', '69', '74', 198.0, 66.0],
#  ['113', 'Aurangzeb', '56', '70', '75', 201.0, 67.0],
#  ['114', 'Zeeshan', '57', '71', '76', 204.0, 68.0],
#  ['115', 'Hamna', '58', '72', '77', 207.0, 69.0],
#  ['116', 'Hamza', '59', '73', '78', 210.0, 70.0],
#  ['117', 'Khalid', '60', '74', '79', 213.0, 71.0],
#  ['118', 'Behroz', '61', '75', '80', 216.0, 72.0],
# ...

# %%
header
# Out:
# ['roll no', 'Name', 'Chemistry', 'Physics', 'Math']

# %%
header.append('Total')
header.append('Percentage')
header
# Out:
# ['roll no', 'Name', 'Chemistry', 'Physics', 'Math', 'Total', 'Percentage']

# %%
new_stud_data.insert(0, header)

# %%
new_stud_data
# Out:
# [['roll no', 'Name', 'Chemistry', 'Physics', 'Math', 'Total', 'Percentage'],
#  ['101', 'Aliza', '50', '23', '87', 160.0, 53.33],
#  ['102', 'Fareed', '45', '24', '88', 157.0, 52.33],
#  ['103', 'Basit', '46', '25', '89', 160.0, 53.33],
#  ['104', 'Abdullah', '47', '26', '90', 163.0, 54.33],
#  ['105', 'Ali', '48', '27', '67', 142.0, 47.33],
#  ['106', 'Mubashir', '49', '28', '68', 145.0, 48.33],
#  ['107', 'Waleed', '50', '29', '69', 148.0, 49.33],
#  ['108', 'Mansoor', '51', '30', '70', 151.0, 50.33],
#  ['109', 'Zain', '52', '31', '71', 154.0, 51.33],
#  ['110', 'Mohsin', '53', '67', '72', 192.0, 64.0],
#  ['111', 'Shahmeer', '54', '68', '73', 195.0, 65.0],
#  ['112', 'Rao', '55', '69', '74', 198.0, 66.0],
#  ['113', 'Aurangzeb', '56', '70', '75', 201.0, 67.0],
#  ['114', 'Zeeshan', '57', '71', '76', 204.0, 68.0],
#  ['115', 'Hamna', '58', '72', '77', 207.0, 69.0],
#  ['116', 'Hamza', '59', '73', '78', 210.0, 70.0],
#  ['117', 'Khalid', '60', '74', '79', 213.0, 71.0],
# ...

# %%
open_file = open('update_student_data.csv', mode = 'w')

# %%
writer = csv.writer(open_file)
writer.writerows(new_stud_data)

# %%
open_file.close()
